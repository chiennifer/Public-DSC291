# %% [markdown]
# # Get files from S3 to cluster

# %% [markdown]
# ## Copy meta information files

# %%
s3helper.open_bucket('mas-dse-open',region='us-west-2')

info_files=s3helper.ls('Weather/Info')
Without_path=[x[13:] for x in info_files]


# !mkdir /mnt/workspace/WeatherInfo

for i in range(len(info_files)-1):   # Last entry is the directory name
    _from=info_files[i]
    _to='/mnt/workspace/WeatherInfo/'+Without_path[i]
    print('From %s to %s'%(_from,_to))
    s3helper.s3_to_local(_from,_to)
# Out:
# From Weather/Info/README.md to /mnt/workspace/WeatherInfo/README.md
# From Weather/Info/US_stations.tsv.gz to /mnt/workspace/WeatherInfo/US_stations.tsv.gz
# From Weather/Info/all_stations.tsv.gz to /mnt/workspace/WeatherInfo/all_stations.tsv.gz
# From Weather/Info/data-source.txt to /mnt/workspace/WeatherInfo/data-source.txt
# From Weather/Info/dist2coast.txt.gz to /mnt/workspace/WeatherInfo/dist2coast.txt.gz
# From Weather/Info/ghcnd-countries.txt to /mnt/workspace/WeatherInfo/ghcnd-countries.txt
# From Weather/Info/ghcnd-readme.txt to /mnt/workspace/WeatherInfo/ghcnd-readme.txt
# From Weather/Info/ghcnd-states.txt to /mnt/workspace/WeatherInfo/ghcnd-states.txt
# From Weather/Info/ghcnd-stations_buffered.txt to /mnt/workspace/WeatherInfo/ghcnd-stations_buffered.txt
# From Weather/Info/ghcnd-version.txt to /mnt/workspace/WeatherInfo/ghcnd-version.txt
# From Weather/Info/stations_projections.pickle to /mnt/workspace/WeatherInfo/stations_projections.pickle

# %% [markdown]
# ### Link to original information
#
# Looking in README.md, you see that all of the data can be downloaded from the noaa web site.
#
# ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/

# %% [markdown]
# ## Open Main data bucket

# %%
s3helper.open_bucket('dse-weather-west-2', region="us-west-2")
s3helper.ls('')
# Out:
# ['.aws',
#  '.bash_profile',
#  '.bashrc',
#  '.conda',
#  '.ipython',
#  '.jupyter',
#  '.local',
#  '.ssh',
#  'ALL.csv.gz',
#  'ALLBootstrap.sh',
#  'MasterBootstrap.sh',
#  'NY.parquet',
#  'PrivateBootstrap.sh',
#  'RunFromTerminal.sh',
#  'US_Weather_with_smoothed.parquet',
#  'US_Weather_with_smoothed.parquet_$folder$',
#  'US_stations.parquet',
#  'US_weather.parquet',
#  'fromLocal',
#  'info',
#  's3helper.py',
#  's3hook.sh',
#  'weather.parquet']

# %% [markdown]
# ## Move data from S3 to HDFS

# %%
# %%time
s3helper.s3_to_hdfs("weather.parquet", "/tmp/weather.parquet")
# Out:
# b"20/05/14 22:58:57 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/_SUCCESS' for reading\n20/05/14 22:58:57 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00000-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:58:59 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00001-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:00 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00002-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:00 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00003-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:02 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00004-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:03 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00005-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:04 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00006-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:06 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00007-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:07 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00008-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:08 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00009-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:10 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00010-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:10 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00011-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:12 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00012-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:13 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00013-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:14 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00014-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:16 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00015-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:17 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00016-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:18 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00017-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:20 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00018-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:21 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00019-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:22 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2/weather.parquet/part-00020-6cb19187-62a0-42ad-9516-e03e05ea0c40-c000.snappy.parquet' for reading\n20/05/14 22:59:23 INFO s3n.S3NativeFileSystem: Opening 's3n://dse-weather-west-2
# b'Found 5 items\n-rw-r--r--   1 hadoop hadoop          0 2020-05-14 23:00 /tmp/stations.parquet/_SUCCESS\n-rw-r--r--   1 hadoop hadoop        894 2020-05-14 23:00 /tmp/stations.parquet/_common_metadata\n-rw-r--r--   1 hadoop hadoop       3107 2020-05-14 23:00 /tmp/stations.parquet/_metadata\n-rw-r--r--   1 hadoop hadoop     777171 2020-05-14 23:00 /tmp/stations.parquet/part-r-00000-1fd04699-91d3-4a2a-9b36-e25c9c5f0376.gz.parquet\n-rw-r--r--   1 hadoop hadoop     860566 2020-05-14 23:00 /tmp/stations.parquet/part-r-00001-1fd04699-91d3-4a2a-9b36-e25c9c5f0376.gz.parquet\n'
# CPU times: user 8 ms, sys: 16 ms, total: 24 ms
# Wall time: 10 s

# %%
print(s3helper.ls_hdfs("/tmp"))
# Out:
# b'Found 3 items\ndrwxrwxrwx   - mapred mapred          0 2020-05-14 22:53 /tmp/hadoop-yarn\ndrwxr-xr-x   - hadoop hadoop          0 2020-05-14 23:00 /tmp/stations.parquet\ndrwxr-xr-x   - hadoop hadoop          0 2020-05-14 23:00 /tmp/weather.parquet\n'
# None

# %% [markdown]
# ## Up to here needs to be executed once each time a spark cluster is created.
# The HDFS files will stay there as long as you keep the cluster on.

# %%
import os
import matplotlib.pyplot as plt
import pyspark.sql.functions as F
import pyspark.sql.types as T

os.getcwd()
os.chdir("/mnt/workspace/Public-DSC291/notebooks/Section2-PCA/Full_Dataset_analysis")
os.getcwd()

from Startup import *
# Out:
# finished standard imports
# dict_items([('spark.executor.memory', '3g'), ('spark.app.name', 'Weather_PCA'), ('spark.executor.cores', '1'), ('spark.default.parallelism', '10'), ('spark.cores.max', '4'), ('spark.logConf', 'True')])
# started SparkContext and SQLContext in 15.69 seconds
# loaded weather.parquet in 8.69 seconds
# loaded stations.parquet in 0.18 seconds
# registered dataframes as tables in 0.20 seconds

# %%
# %%time
query1="""
SELECT stations.ID, stations.state, stations.latitude, stations.longitude,
        weather.Measurement, weather.Year, weather.Values
FROM stations
LEFT JOIN weather
ON stations.ID = weather.Station
WHERE stations.state <> '' AND weather.Measurement='PRCP'
"""

query2="""
SELECT stations.ID, stations.state, stations.latitude, stations.longitude,
        weather.Measurement, weather.Year, weather.Values
FROM stations
LEFT JOIN weather
ON stations.ID = weather.Station
WHERE stations.state <> '' AND weather.Measurement='SNOW'
"""

PRCP_df = sqlContext.sql(query1)
SNOW_df = sqlContext.sql(query2)
sqlContext.registerDataFrameAsTable(PRCP_df,'PRCP_df')
sqlContext.registerDataFrameAsTable(SNOW_df,'SNOW_df')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 146 ms

# %%
query="""
SELECT stations.ID, stations.state, stations.latitude, stations.longitude,
        weatherA.Year, weatherA.Values as PRCP, weatherB.Values as SNOW
FROM stations, weather as weatherA, weather as weatherB
WHERE stations.state <> '' AND 
        stations.ID = weatherA.Station AND
        stations.ID = weatherB.Station AND
        weatherA.Year = weatherB.Year AND
        weatherA.Measurement = 'PRCP' AND
        weatherB.Measurement = 'SNOW'
"""

Weather_df = sqlContext.sql(query)
sqlContext.registerDataFrameAsTable(Weather_df, 'Weather_df')

# %%
#Filter for certain dates
filter_year = 1945
Weather_df = Weather_df.filter(Weather_df.Year > filter_year)

#Filter for only stations with data in the full range
cnt_bystation = Weather_df.groupBy('ID').count()
Weather_df = Weather_df.join(cnt_bystation, "ID")
mx = cnt_bystation.agg({"count": "max"}).collect()[0]["max(count)"]
Weather_df = Weather_df.filter(Weather_df['count'] == mx)
Weather_pdf = Weather_df.toPandas()

# %%
def f1(row, col):
    return row[col][:362]

def f2(row, col):
    return row[col][362:]

def Jan2Jun(df, col):
    df_first = df.copy()
    
    # df_first is same as df except for its ['Values'] column only contains the 
    # the first half year data.
    df_first['V_first'] = df_first.apply(f1, axis=1, args=[col])
    
    # subtract df_first 'Year' column by 1, because we want to join originally 1998 Jan-Jun to 1997 July-Dec,
    # as 1997 data, so minus 1998 by 1 to match 1997.
    df_first['Year'] = df_first.apply(lambda x: x['Year']-1, axis=1)
    
    # df_second is same as df except for its ['Values'] column only contains the 
    # the second half year data.
    df_second = df.copy()
    df_second['V_second'] = df_second.apply(f2, axis=1, args=[col])
    
    # drop the inrrelevant columns of df_second so that join can be easier later. I only kept 'ID' and 'Year'
    # that are used to be joined on later.
    df_second = df_second.drop(['state', 'latitude', 'SNOW', 'PRCP',
                                'longitude', 'count', col], axis=1)
    
    # join df_first and df_second on ID, Year.
    result = pd.merge(df_first, df_second, on=['ID', 'Year'], how='inner')
    
    # generate the thansformed data, e.g. 1997 July - 1998 June from 'V_second' (1997 July - 1997 Dec) and 
    # 'V_first' (1998 Jan - 1998 June)
    result[col] = result.apply(lambda x: x['V_second'] + x['V_first'], axis=1)
    
    # drop V_second and V_first as they are useless now.
    return result.drop(['V_second', 'V_first'], axis=1)

# %%
New_Weather_pdf = Jan2Jun(Weather_pdf, 'PRCP')
New_Weather_pdf = Jan2Jun(New_Weather_pdf, 'SNOW')
del New_Weather_pdf['count']
PRCP = [np.nansum(unpackArray(v,np.float16)) for v in list(New_Weather_pdf['PRCP'])]
SNOW = [np.nansum(unpackArray(v,np.float16)) for v in list(New_Weather_pdf['SNOW'])]
New_Weather_pdf['PRCP'] = PRCP
New_Weather_pdf['SNOW'] = SNOW
New_Weather_pdf.sample(5)

# %%
# Filter stations only in US
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
df_ElNinoYears = pd.read_csv(url + '/US_Unemployment_Oct2012.csv')
US_states = list(df_ElNinoYears['State'])
pick = [New_Weather_pdf['state'][i] in US_states for i in New_Weather_pdf.index]
New_Weather_pdf = New_Weather_pdf[pick]
In [83]:
ElNinoYears = [1951, 1957, 1965, 1968, 1972, 197

# %%
ElNinoYears = [1951, 1957, 1965, 1968, 1972, 1977, 1982, 1991, 1997]
data = []
row_num = 0
for station in set(New_Weather_pdf['ID']):
    row_num = row_num + 1
    temp_pdf = New_Weather_pdf[New_Weather_pdf['ID']==station]
    temp_pdf.index = range(len(temp_pdf))
    state = temp_pdf['state'][0]
    lat = temp_pdf['latitude'][0]
    lon = temp_pdf['longitude'][0]
    pick_EN = np.array([temp_pdf['Year'][i] in ElNinoYears for i in temp_pdf.index])
    PRCP_EN =temp_pdf[pick_EN]['PRCP'].mean()
    PRCP_NEN = temp_pdf[~pick_EN]['PRCP'].mean()
    SNOW_EN = temp_pdf[pick_EN]['SNOW'].mean()
    SNOW_NEN = temp_pdf[~pick_EN]['SNOW'].mean()
    data.append([row_num, station, state, lat, lon, PRCP_EN, PRCP_NEN, SNOW_EN, SNOW_NEN])
    
df = pd.DataFrame(data, columns=['row_num','station', 'state', 'latitude', 
                                 'longitude', 'PRCP_EN', 'PRCP_NEN', 
                                 'SNOW_EN', 'SNOW_NEN'])
df
# Out:
#       row_num      station state  latitude  longitude       PRCP_EN  \
# 0           1  USC00203858    MI   42.7989   -86.2050   9580.888889
# 1           2  USC00142432    KS   37.0058  -101.8867   4662.666667
# 2           3  USC00362183    PA   40.1275   -79.4058  10264.888889
# 3           4  USW00013957    LA   32.4506   -93.8411  12772.000000
# 4           5  USC00425065    UT   39.5608  -111.8653   3764.888889
# 5           6  USC00395228    SD   43.4206   -97.2567   6911.111111
# 6           7  USC00215563    MN   44.9342   -95.7461   6764.888889
# 7           8  USC00219249    MN   44.2992   -92.6661   8153.777778
# 8           9  USC00104670    ID   42.7325  -114.5192   2719.444444
# 9          10  USC00456898    WA   46.7858  -121.7425  27140.000000
# 10         11  USC00290600    NM   32.7547  -104.3836   2914.111111
# 11         12  USC00478905    WI   45.3581   -86.8911   7255.555556
# 12         13  USC00334979    OH   40.2411   -83.3669   9399.555556
# 13         14  USC00397742    SD   45.6656   -97.0392   5387.555556
# 14         15  USC00334874    OH   40.7667   -82.6167   9468.444444
# 15         16  USC00030326    AR   35.2894   -91.3533  12176.000000
# 16         17  USC00353827    OR   45.3653  -119.5639   3790.666667
# 17         18  USC00141795    KS   37.3842   -97.6431   7451.555556
# 18         19  USC00422828    UT   38.9664  -112.3278   3926.000000
# 19         20  USC00213567    MN   44.7597   -92.8689   7254.666667
# 20         21  USC00255925    NE   42.6008   -99.3333   6065.333333
# 21         22  USC00130753    IA   40.7597   -92.4394  10000.888889
# 22         23  USC00148287    KS   37.5983  -101.2908   3305.777778
# 23         24  USW00013995    MO   37.2353   -93.4003  11878.222222
# 24         25  USC00411250    TX   30.7586   -98.2339   7579.111111
# 25         26  USC00428119    UT   40.0797  -111.6044   5365.111111
# 26         27  USC00210355    MN   43.6542   -92.9739   7895.555556
# 27         28  USC00301413    NY   42.0025   -76.6383   8881.333333
# 28         29  USC00248957    MT   46.9878  -104.1567   3421.333333
# 29         30  USC00368873    PA   41.4792   -79.4433  11082.666667
# ...       ...          ...   ...       ...        ...           ...
# 1006     1007  USC00250435    NE   40.3706   -95.7469   9233.777778
# 1007     1008  USC00143974    KS   38.1869   -97.8417   8066.888889
# 1008     1009  USC00471131    WI   46.5378   -91.5919   8961.777778
# 1009     1010  USC00459238    WA   47.7567  -118.6775   3547.777778
# 1010     1011  USC00222385    MS   31.9544   -89.9328  14444.444444
# 1011     1012  USC00425733    UT   38.5744  -109.5458   2209.777778
# 1012     1013  USW00014819    IL   41.7861   -87.7522  10323.555556
# 1013     1014  USC00454338    WA   46.8167  -117.8831   3837.333333
# 1014     1015  USC00114823    IL   40.5839   -90.9686   9815.555556
# 1014   9451.719298    771.666667    608.035088
# 1015  11535.719298   2554.777778   2304.315789
# 1016   5847.000000    975.222222    930.631579
# 1017   2420.631579    583.888889    330.631579
# 1018   6734.280702    628.666667    604.508772
# 1019   4626.122807    566.777778    707.578947
# 1020  10231.859649     80.000000     18.052632
# 1021   2642.877193    911.111111    949.017544
# 1022   9563.052632    608.666667    490.754386
# 1023   8707.157895    485.888889    319.614035
# 1024   6905.105263   1000.888889    903.315789
# 1025   3636.877193   3868.666667   2909.473684
# 1026  13007.087719    341.666667    267.385965
# 1027   3806.596491   2453.777778   1975.491228
# 1028   8208.491228    423.666667    314.385965
# 1029   9648.982456    383.888889    621.456140
# 1030   6143.982456    989.888889    703.508772
# 1031   9906.666667    434.888889    429.438596
# 1032   9084.631579    701.444444    636.140351
# 1033   3109.087719   1431.222222   1485.526316
# 1034   5183.859649   1023.444444   1041.438596
# 1035   6506.385965   4572.222222   4311.982456
#
# [1036 rows x 9 columns]

# %% [markdown]
# ### DATA: Descriptives
#
# Let’s take a look at the data!

# %%
df[['PRCP_EN','PRCP_NEN', 'SNOW_EN', 'SNOW_NEN']].describe()
# Out:
#             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754

# %% [markdown]
# Takeaways:
# 1. We have Snow and Precipitation data for 1036 stations during el-nino and non el-nino years
# 2. Mean precipitation is higher during El nino years than in Non- El nino years. Similarly, there's more snow in the El nino years than in the Non el nino years. However, are these significant? We need to do a paired samples t-test to test this out.
# 3. Precipitation data is more variable than snow data.

# %%
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# ### Assumption Check: Outliers
#
# First thing we need to do is import the stats library and then test the assumptions of the paired samples t-test. First let’s check for any significant outliers in each of the variables.

# %%
df[['PRCP_EN','PRCP_NEN']].plot(kind='box')
# This saves the plot as a png file
plt.show()

# %%
df[['SNOW_EN','SNOW_NEN']].plot(kind='box')
# This saves the plot as a png file
#plt.savefig('boxplot_outliers.png')
plt.show()

# %% [markdown]
# Takeaways:
# 1. The Precipitation data has a larger range (i.e. more variable) when compared to the snow data.
# 2. There are a few outliers in both precipitation data and snow. However, the outliers in the snow data seem to be more significant outliers.

# %% [markdown]
# ### Assumption Check: Normal Distribution
#
# Remember that for the dependent sample T-test the normality check needs to be conducted on differences between the two scores. There are a few ways one can test this assumption – make a histogram, use a Q-Q plot, and/or use a statistical test. Let’s create a variable for the differences and run through these.

# %%
df['PRCP_DIFF'] = df['PRCP_NEN'] - df['PRCP_EN']

df['PRCP_DIFF'].plot(kind='hist', title= 'Precipitation Difference Histogram')
plt.show()

# %%
df['SNOW_DIFF'] = df['SNOW_NEN'] - df['SNOW_EN']

df['SNOW_DIFF'].plot(kind='hist', title= 'Snow Difference Histogram')
plt.show()

# %% [markdown]
# Takeaways:
# 1. Precipitation data seems to be normally distributed.
# 2. Snow data is positively skewed, not normally distributed.

# %% [markdown]
# ### Q-Q plot
#
# Another way to check for normally distributed data is to use a Q-Q plot. If you’re unfamiliar with how to read a Q-Q plot, the data should be on the red line. If it’s not, then it suggests that the data may not be normally distributed.

# %%
stats.probplot(df['PRCP_DIFF'], plot= plt)
plt.title('Precipitation Difference Q-Q Plot')

# %%
stats.probplot(df['SNOW_DIFF'], plot= plt)
plt.title('Snow Difference Q-Q Plot')

# %% [markdown]
# There is some deviation from normality, but it does not appear to be severe so there is no need to worry. To be sure, let’s test this statistically to see if the data is normally distributed. To test this, one can use the Shapiro-Wilk test for normality. Unfortunately the output is not labeled. The first value is the W test value, and the second value it the p-value.

# %%
stats.shapiro(df['PRCP_DIFF'])
# Out:
# (0.9840223789215088, 3.137212711834536e-09)

# %%
stats.shapiro(df['SNOW_DIFF'])
# Out:
# (0.8900324702262878, 1.602889554806485e-26)

# %% [markdown]
# The test was non-significant. Therefore, the difference between the two conditions is normally distributed. If this test were to be significant, an appropriate alternative to use would be the Wilcoxon signed-rank Test.

# %% [markdown]
# ## Paired Samples T-Test

# %%
stats.ttest_rel(df['PRCP_EN'], df['PRCP_NEN'])
# Out:
# Ttest_relResult(statistic=16.77867955867935, pvalue=4.5187402770054652e-56)

# %%
stats.ttest_ind(df['PRCP_EN'], df['PRCP_NEN'])
# Out:
# Ttest_indResult(statistic=2.1262829336706388, pvalue=0.033597736591003707)

# %% [markdown]
# ### Interpretation of the Paired Samples T-Test Results
#
# A paired sample t-test was used to analyze the precipitation in el nino years and in non el nino years to test if the el nino had a significant affect on the precipitation. The precipitation in el nino years was higher (7978.62 ± 3301.84 units) compared to the precipitation in non el nino years (7674.57 ± 3206.67 units). However, this was not a statistically significant difference at p$<0.05$ for the entire US.

# %% [markdown]
# ### Interpretation of the Independent Samples T-Test Results
#
# An independent samples t-test was used to analyze the precipitation in el nino years and in non el nino years to test if the el nino had a significant affect on the precipitation. The precipitation in el nino years was higher (7978.62 ± 3301.84 units) compared to the precipitation in non el nino years (7674.57 ± 3206.67 units). However, this was statistically significant difference at p$=0.03$ for the entire US.

# %%
stats.ttest_rel(df['SNOW_EN'], df['SNOW_NEN'])
# Out:
# Ttest_relResult(statistic=13.232045374531031, pvalue=4.8500165799108326e-37)

# %%
stats.ttest_ind(df['SNOW_EN'], df['SNOW_NEN'])
# Out:
# Ttest_indResult(statistic=1.7853120414280366, pvalue=0.074357087706248923)

# %% [markdown]
# ### Interpretation of the Results
#
# A paired sample t-test was used to analyze the snow fall in el nino years and in non el nino years to test if the el nino had a significant affect on the precipitation. The snow fall in el nino years was higher (889.41 ± 928.53 units) compared to the precipitation in non el nino years (819.17 ± 861.24 units). However, this was not a statistically significant difference at p$<0.05$ for the entire US.

# %% [markdown]
# ### Interpretation of the Independent Samples T-Test Results
#
# An independent samples t-test was used to analyze the precipitation in el nino years and in non el nino years to test if the el nino had a significant affect on the precipitation. The precipitation in el nino years was higher (7978.62 ± 3301.84 units) compared to the precipitation in non el nino years (7674.57 ± 3206.67 units). However, this was moderately significant difference at p$=0.07$ for the entire US.

# %% [markdown]
# ## Comparing Precipitation and Snow Fall at the Station level

# %%
data = []
for index, row in df.iterrows():
    Station = row['station']
    State = row['state']
    lat = row['latitude']
    lon = row['longitude']
    PRCP_EN = row['PRCP_EN']
    PRCP_NEN = row['PRCP_NEN']
    PRCP_DIFF = row['PRCP_EN'] - row['PRCP_NEN']
    SNOW_EN = row['SNOW_EN']
    SNOW_NEN = row['SNOW_NEN']
    SNOW_DIFF = row['SNOW_EN'] - row['SNOW_NEN']
    PRCP_Test = stats.ttest_rel(row['PRCP_EN'], row['PRCP_NEN'])
    PRCP_Test = stats.ttest_ind(row['PRCP_EN'], row['PRCP_NEN'])
    SNOW_Test = stats.ttest_rel(row['SNOW_EN'], row['SNOW_NEN'])
    data.append([Station, State, lat, lon, PRCP_EN, PRCP_NEN, PRCP_DIFF, PRCP_Test, SNOW_EN, SNOW_NEN,  SNOW_DIFF, SNOW_Test])
    #print(Station, State, PRCP_DIFF, PRCP_Test, SNOW_DIFF , SNOW_Test)

df = pd.DataFrame(data, columns=['station', 'state', 'latitude', 'longitude', 
                                 'PRCP_EN', 'PRCP_NEN', 'PRCP_DIFF', 'PRCP_Test',
                                 'SNOW_EN', 'SNOW_NEN', 'SNOW_DIFF', 'SNOW_Test'])
df
# Out:
# /mnt/anaconda/envs/ipykernel_py34/lib/python3.4/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /mnt/anaconda/envs/ipykernel_py34/lib/python3.4/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#           station state  latitude  longitude        PRCP_EN      PRCP_NEN  \
# 0     USC00203858    MI   42.7989   -86.2050   38323.555556   9240.842105
# 1     USC00142432    KS   37.0058  -101.8867   18650.666667   4279.368421
# 2     USC00362183    PA   40.1275   -79.4058   41059.555556  10431.614035
# 3     USW00013957    LA   32.4506   -93.8411   51088.000000  11791.368421
# 4     USC00425065    UT   39.5608  -111.8653   15059.555556   3530.385965
# 5     USC00395228    SD   43.4206   -97.2567   27644.444444   5925.280702
# 6     USC00215563    MN   44.9342   -95.7461   27059.555556   6672.456140
# 7     USC00219249    MN   44.2992   -92.6661   32615.111111   7736.070175
# 8     USC00104670    ID   42.7325  -114.5192   10877.777778   2559.842105
# 9     USC00456898    WA   46.7858  -121.7425  108560.000000  25997.263158
# 10    USC00290600    NM   32.7547  -104.3836   11656.444444   2876.385965
# 11    USC00478905    WI   45.3581   -86.8911   29022.222222   7028.456140
# 12    USC00334979    OH   40.2411   -83.3669   37598.222222   9381.192982
# 13    USC00397742    SD   45.6656   -97.0392   21550.222222   5622.982456
# 14    USC00334874    OH   40.7667   -82.6167   37873.777778   9353.894737
# 15    USC00030326    AR   35.2894   -91.3533   48704.000000  12103.228070
# 16    USC00353827    OR   45.3653  -119.5639   15162.666667   3432.087719
# 17    USC00141795    KS   37.3842   -97.6431   29806.222222   7894.666667
# 18    USC00422828    UT   38.9664  -112.3278   15704.000000   3738.280702
# 19    USC00213567    MN   44.7597   -92.8689   29018.666667   7251.859649
# 20    USC00255925    NE   42.6008   -99.3333   24261.333333   5882.701754
# 21    USC00130753    IA   40.7597   -92.4394   40003.555556   9085.614035
# 22    USC00148287    KS   37.5983  -101.2908   13223.111111   4110.403509
# 23    USW00013995    MO   37.2353   -93.4003   47512.888889  10450.035088
# 24    USC00411250    TX   30.7586   -98.2339   30316.444444   7418.315789
# 1026  41264.912281  (nan, nan)    341.666667    267.385965    74.280702
# 1027  13297.403509  (nan, nan)   2453.777778   1975.491228   478.286550
# 1028  25654.619883  (nan, nan)    423.666667    314.385965   109.280702
# 1029  28589.239766  (nan, nan)    383.888889    621.456140  -237.567251
# 1030  20814.239766  (nan, nan)    989.888889    703.508772   286.380117
# 1031  27446.222222  (nan, nan)    434.888889    429.438596     5.450292
# 1032  27192.701754  (nan, nan)    701.444444    636.140351    65.304094
# 1033  10196.690058  (nan, nan)   1431.222222   1485.526316   -54.304094
# 1034  16522.807018  (nan, nan)   1023.444444   1041.438596   -17.994152
# 1035  20108.725146  (nan, nan)   4572.222222   4311.982456   260.239766
#
#        SNOW_Test
# 0     (nan, nan)
# 1     (nan, nan)
# 2     (nan, nan)
# 3     (nan, nan)
# 4     (nan, nan)
# 5     (nan, nan)
# 6     (nan, nan)
# 7     (nan, nan)
# 8     (nan, nan)
# 9     (nan, nan)
# 10    (nan, nan)
# 11    (nan, nan)
# 12    (nan, nan)
# 13    (nan, nan)
# 14    (nan, nan)
# 15    (nan, nan)
# 16    (nan, nan)
# 17    (nan, nan)
# 18    (nan, nan)
# 19    (nan, nan)
# 20    (nan, nan)
# 21    (nan, nan)
# 22    (nan, nan)
# 23    (nan, nan)
# 24    (nan, nan)
# 25    (nan, nan)
# 26    (nan, nan)
# 27    (nan, nan)
# 28    (nan, nan)
# 29    (nan, nan)
# ...          ...
# 1006  (nan, nan)
# 1007  (nan, nan)
# 1008  (nan, nan)
# 1009  (nan, nan)
# 1010  (nan, nan)
# 1011  (nan, nan)
# 1012  (nan, nan)
# 1013  (nan, nan)
# 1014  (nan, nan)
# 1015  (nan, nan)
# 1016  (nan, nan)
# 1017  (nan, nan)
# 1018  (nan, nan)
# 1019  (nan, nan)
# 1020  (nan, nan)
# 1021  (nan, nan)
# 1022  (nan, nan)
# 1023  (nan, nan)
# 1024  (nan, nan)
# 1025  (nan, nan)
# 1026  (nan, nan)
# 1027  (nan, nan)
# 1028  (nan, nan)
# 1029  (nan, nan)
# 1030  (nan, nan)
# 1031  (nan, nan)
# 1032  (nan, nan)
# 1033  (nan, nan)
# 1034  (nan, nan)
# 1035  (nan, nan)
#
# [1036 rows x 12 columns]

# %% [markdown]
# ### Are there any significant differences at the State level?

# %%
for state in set(df['state']):
    s = df[['PRCP_EN','PRCP_NEN', 'SNOW_EN', 'SNOW_NEN']].describe()
    print(state, s)
# Out:
# CA             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# UT             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# WA             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# IA             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# TN             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# SD             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# MO             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# ND             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# TX             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# NM             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# AR             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# LA             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# AZ             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# GA             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# OK             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# KY             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# AK             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# MI             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# NH             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# IL             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# NE             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# ME             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# NY             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# SC             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# OR             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# MN             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# MA             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# MD             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# VA             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# WV             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# FL             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# OH             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# ID             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# NJ             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# CO             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# CT             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# NV             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# NC             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# KS             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# WI             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# MS             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# PA             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# IN             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# MT             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# VT             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# AL             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754
# WY             PRCP_EN      PRCP_NEN       SNOW_EN      SNOW_NEN
# count   1036.000000   1036.000000   1036.000000   1036.000000
# mean    7978.625161   7674.568465    889.412698    819.166277
# std     3301.842068   3206.673850    928.531874    861.242235
# min      808.777778    895.649123      0.000000      0.000000
# 25%     5356.111111   5230.087719    373.361111    338.710526
# 50%     8349.333333   7799.403509    758.444444    638.043860
# 75%    10090.888889   9784.789474   1123.277778   1008.263158
# max    28707.555556  27003.368421  16774.000000  15183.701754

# %%
ElNinoYears = [1951, 1957, 1965, 1968, 1972, 1977, 1982, 1991, 1997]
data = []
for state in set(New_Weather_pdf['state']):
    temp_pdf = New_Weather_pdf[New_Weather_pdf['state']==state]
    temp_pdf.index = range(len(temp_pdf))
    lat = temp_pdf['latitude'][0]
    lon = temp_pdf['longitude'][0]
    pick_EN = np.array([temp_pdf['Year'][i] in ElNinoYears for i in temp_pdf.index])
    PRCP_EN =temp_pdf[pick_EN]['PRCP'].mean()
    PRCP_NEN = temp_pdf[~pick_EN]['PRCP'].mean()
    SNOW_EN = temp_pdf[pick_EN]['SNOW'].mean()
    SNOW_NEN = temp_pdf[~pick_EN]['SNOW'].mean()
    data.append([state, lat, lon, PRCP_EN, PRCP_NEN, SNOW_EN, SNOW_NEN])
    
df = pd.DataFrame(data, columns=['state', 'latitude', 
                                 'longitude', 'PRCP_EN', 'PRCP_NEN', 
                                 'SNOW_EN', 'SNOW_NEN'])
df
# Out:
#    state  latitude  longitude       PRCP_EN      PRCP_NEN      SNOW_EN  \
# 0     CA   35.7636  -117.3908   6357.756614   5784.398496   868.492063
# 1     UT   38.9664  -112.3278   3400.570707   3292.087719  1012.848485
# 2     WA   47.7567  -118.6775   6746.742424   6391.696172  1737.813131
# 3     IA   42.5189   -93.2536   8849.465517   8093.450998   850.224138
# 4     TN   35.8575   -84.5278  12725.196581  12518.483131   188.752137
# 5     SD   42.9939   -97.8619   5423.183333   5016.890789   994.991667
# 6     MO   39.3447   -91.1711  10438.435897   9771.324786   458.623932
# 7     ND   46.1825  -103.4061   4611.981481   4506.220760   980.324074
# 8     TX   28.5033   -98.8392   6185.666667   6271.116509    63.854701
# 9     NM   34.8242  -106.0344   3609.368421   3678.635272   507.906433
# 10    AR   34.5128   -93.0486  12830.018519  12401.081871    96.864198
# 11    LA   32.6053   -93.2947  14287.222222  13551.614035     8.055556
# 12    AZ   34.7522  -112.1114   3893.507937   3893.129073   840.134921
# 13    GA   34.4758   -84.4461  12958.222222  12670.245614    23.074074
# 14    OK   36.7683   -96.0261   7405.156250   7809.144189   167.350694
# 15    KY   36.7458   -86.2258  11626.962963  11779.529240   315.888889
# 16    AK   55.0389  -131.5786  16411.777778  15648.394737  1747.833333
# 17    MI   45.0717   -83.5644   8169.927928   7989.607871  1794.306306
# 18    NH   43.1953   -71.5011  10496.825397  10944.075188  2021.222222
# 19    IL   41.7806   -88.3092  10074.995272   9348.324001   670.463357
# 20    NE   42.0650  -100.2472   6589.523392   5870.918975   858.434211
# 21    ME   47.2386   -68.6136  10714.444444  10517.109649  1973.430556
# 22    NY   41.7681   -74.1550   9578.507937   9892.755013  1811.000000
# 23    SC   33.8314   -79.0558  12083.777778  12347.807018    19.277778
# 24    OR   45.4825  -120.7236   7757.879227   7032.777269   593.748792
# 25    MN   47.7517   -90.3578   7374.165312   6939.609328  1069.271003
# 26    MA   42.2122   -71.1136  11963.070707  11529.138756  1091.797980
# 27    MD   39.6556   -76.1756  10525.888889  10861.578947   903.416667
# 28    VA   37.7767   -79.4386  10269.333333  10495.993536   418.052632
# 29    WV   39.5436   -80.4647  10307.940741  10454.516959   597.222222
# 30    FL   27.9619   -82.5403  13220.000000  12922.385965     0.000000
# 31    OH   41.0461   -83.6622   9791.349206   9648.897243   818.908730
# 32    ID   48.3511  -116.8353   5129.189815   4731.803363  1406.532407
# 33    NJ   40.5631   -74.8831  11500.177778  11185.768421   657.266667
# 34    CO   38.8247  -106.1275   3827.611111   3702.156347  1778.333333
# 35    CT   41.9725   -73.2208  12588.000000  12140.491228  1514.500000
# 36    NV   35.4661  -114.9217   2195.650794   2177.395990   543.730159
# 37    NC   36.3919   -81.3039  11758.577778  11763.600000   195.133333
# 38    WI   46.0003   -91.5075   8296.265537   7870.526316  1204.403013
# 39    KS   39.1972   -96.5814   7501.319444   6907.725877   593.710069
# 40    MS   31.2547   -89.3392  14322.222222  13972.914474    25.208333
# 41    PA   40.1467   -79.8986  10609.287356  10671.461585  1118.417625
# 42    IN   40.9706   -85.2064  10647.536232  10433.067887   579.429952
# 43    MT   48.9761  -111.3994   4201.144444   4107.924561  1569.794444
# 44    AL   34.6736   -86.0536  12832.444444  13812.807018    46.500000
# 45    VT   43.2667   -72.9000  10057.888889  10152.982456  2126.291667
# 46    WY   41.1519  -104.8061   3436.444444   3087.800000  1258.511111
#
#        SNOW_NEN
# 0    866.654135
# 1    943.956938
# 2   1718.709729
# 3    745.495463
# 4    170.933873
# 5    956.479825
# 6    368.301395
# 7    903.013158
# 8     94.406208
# 9    598.078486
# 10   108.675439
# 11    21.824561
# 12   934.860902
# 13    26.105263
# 14   180.445724
# 15   313.868421
# 16  1715.535088
# 17  1699.352300
# 18  2158.177945
# 19   504.956327
# 20   690.836103
# 21  2069.739035
# 22  1728.259398
# 23    26.385965
# 24   544.354691
# 25  1002.096705
# 26  1078.065391
# 27   937.004386
# 28   417.898430
# 29   626.035088
# 30     0.394737
# 31   726.857143
# 32  1307.508772
# 33   659.694737
# 34  1587.166151
# 35  1511.850877
# 36   555.721805
# 37   198.521930
# 38  1115.418971
# 39   435.581140
# 40    43.964912
# 41  1049.728978
# 42   464.720061
# 43  1453.380702
# 44    32.921053
# 45  2085.695175
# 46  1103.850877

# %%
df[['PRCP_EN','PRCP_NEN']].plot(kind='box')
# This saves the plot as a png file
plt.show()

# %%
df[['SNOW_EN','SNOW_NEN']].plot(kind='box')
# This saves the plot as a png file
#plt.savefig('boxplot_outliers.png')
plt.show()

# %%
df['PRCP_DIFF'] = df['PRCP_NEN'] - df['PRCP_EN']

df['PRCP_DIFF'].plot(kind='hist', title= 'Precipitation Difference Histogram')
plt.show()

# %%
df['SNOW_DIFF'] = df['SNOW_NEN'] - df['SNOW_EN']

df['SNOW_DIFF'].plot(kind='hist', title= 'Snow Difference Histogram')
plt.show()

# %%
stats.probplot(df['PRCP_DIFF'], plot= plt)
plt.title('Precipitation Difference Q-Q Plot')

# %%
stats.probplot(df['SNOW_DIFF'], plot= plt)
plt.title('Snow Difference Q-Q Plot')

# %%
stats.shapiro(df['PRCP_DIFF'])
# Out:
# (0.9618613123893738, 0.12751539051532745)

# %%
stats.shapiro(df['SNOW_DIFF'])
# Out:
# (0.9699710011482239, 0.26426902413368225)

# %%
stats.ttest_rel(df['PRCP_EN'], df['PRCP_NEN'])
# Out:
# Ttest_relResult(statistic=3.4803348675638448, pvalue=0.0011077308811293003)

# %%
stats.ttest_rel(df['SNOW_EN'], df['SNOW_NEN'])
# Out:
# Ttest_relResult(statistic=3.2503901365879506, pvalue=0.0021586915103055052)

# %%
data = []
for index, row in df.iterrows():
    State = row['state']
    lat = row['latitude']
    lon = row['longitude']
    PRCP_EN = row['PRCP_EN']
    PRCP_NEN = row['PRCP_NEN']
    PRCP_DIFF = row['PRCP_EN'] - row['PRCP_NEN']
    SNOW_EN = row['SNOW_EN']
    SNOW_NEN = row['SNOW_NEN']
    SNOW_DIFF = row['SNOW_EN'] - row['SNOW_NEN']
    PRCP_Test = stats.ttest_rel(row['PRCP_EN'], row['PRCP_NEN'])
    PRCP_Test = stats.ttest_ind(row['PRCP_EN'], row['PRCP_NEN'])
    SNOW_Test = stats.ttest_rel(row['SNOW_EN'], row['SNOW_NEN'])
    data.append([State, lat, lon, PRCP_EN, PRCP_NEN, PRCP_DIFF, PRCP_Test, SNOW_EN, SNOW_NEN,  SNOW_DIFF, SNOW_Test])
    #print(Station, State, PRCP_DIFF, PRCP_Test, SNOW_DIFF , SNOW_Test)

df = pd.DataFrame(data, columns=['state', 'latitude', 'longitude', 
                                 'PRCP_EN', 'PRCP_NEN', 'PRCP_DIFF', 'PRCP_Test',
                                 'SNOW_EN', 'SNOW_NEN', 'SNOW_DIFF', 'SNOW_Test'])
df
# Out:
# /mnt/anaconda/envs/ipykernel_py34/lib/python3.4/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /mnt/anaconda/envs/ipykernel_py34/lib/python3.4/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#    state  latitude  longitude       PRCP_EN      PRCP_NEN   PRCP_DIFF  \
# 0     CA   35.7636  -117.3908   6357.756614   5784.398496  573.358118
# 1     UT   38.9664  -112.3278   3400.570707   3292.087719  108.482988
# 2     WA   47.7567  -118.6775   6746.742424   6391.696172  355.046252
# 3     IA   42.5189   -93.2536   8849.465517   8093.450998  756.014519
# 4     TN   35.8575   -84.5278  12725.196581  12518.483131  206.713450
# 5     SD   42.9939   -97.8619   5423.183333   5016.890789  406.292544
# 6     MO   39.3447   -91.1711  10438.435897   9771.324786  667.111111
# 7     ND   46.1825  -103.4061   4611.981481   4506.220760  105.760721
# 8     TX   28.5033   -98.8392   6185.666667   6271.116509  -85.449843
